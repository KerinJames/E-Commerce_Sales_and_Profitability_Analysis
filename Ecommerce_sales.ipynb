# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###Read File and verify

# %%
#upload dataset

from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-30204f6c-1c5b-44bd-ab98-3c36fb47930a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30204f6c-1c5b-44bd-ab98-3c36fb47930a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#read dataset

df = pd.read_csv("ecommerce_sales.csv", encoding = 'latin1')

# %%
#check data

df.head()
# Out:
#   order_id customer_id product_id     category   price  discount  quantity  \
# 0  O100000      C17270    P234890         Home  164.08      0.15         1
# 1  O100001      C17603    P228204      Grocery   24.73      0.00         1
# 2  O100002      C10860    P213892  Electronics  175.58      0.05         1
# 3  O100003      C15390    P208689  Electronics   63.67      0.00         1
# 4  O100004      C15226    P228063         Home   16.33      0.15         1
#
#   payment_method  order_date  delivery_time_days region returned  \
# 0    Credit Card  2023-12-23                   4   West       No
# 1    Credit Card  2025-04-03                   6  South       No
# 2    Credit Card  2024-10-08                   4  North       No
# 3            UPI  2024-09-14                   6  South       No
# 4            COD  2024-12-21                   6   East       No
#
#    total_amount  shipping_cost  profit_margin  customer_age customer_gender
# ...

# %%
df.tail()
# Out:
#       order_id customer_id product_id     category   price  discount  \
# 34495  O134495      C13553    P231412      Fashion   10.44      0.20
# 34496  O134496      C11349    P218266       Beauty    4.79      0.10
# 34497  O134497      C12986    P204345  Electronics  323.64      0.00
# 34498  O134498      C17196    P217644         Home   23.09      0.05
# 34499  O134499      C13330    P207047         Home   76.84      0.00
#
#        quantity payment_method  order_date  delivery_time_days region  \
# 34495         1     Debit Card  2025-08-13                   3  North
# 34496         5     Debit Card  2023-12-04                   6  South
# 34497         5    Credit Card  2025-02-01                   6   East
# 34498         1    Credit Card  2024-03-27                   6   East
# 34499         1     Debit Card  2025-09-11                   6   East
#
#       returned  total_amount  shipping_cost  profit_margin  customer_age  \
# ...

# %%
print(f"No of rows : {df.shape[0]}")

print(f"No of columns : {df.shape[1]}")
# Out:
# No of rows : 34500
# No of columns : 17

# %%
#basic information


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34500 entries, 0 to 34499
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            34500 non-null  object
#  1   customer_id         34500 non-null  object
#  2   product_id          34500 non-null  object
#  3   category            34500 non-null  object
#  4   price               34500 non-null  float64
#  5   discount            34500 non-null  float64
#  6   quantity            34500 non-null  int64
#  7   payment_method      34500 non-null  object
#  8   order_date          34500 non-null  object
#  9   delivery_time_days  34500 non-null  int64
#  10  region              34500 non-null  object
#  11  returned            34500 non-null  object
#  12  total_amount        34500 non-null  float64
#  13  shipping_cost       34500 non-null  float64
#  14  profit_margin       34500 non-null  float64
# ...

# %% [markdown]
# ###Check missing values

# %%
#missing values

df.isnull().sum()
# Out:
# order_id              0
# customer_id           0
# product_id            0
# category              0
# price                 0
# discount              0
# quantity              0
# payment_method        0
# order_date            0
# delivery_time_days    0
# region                0
# returned              0
# total_amount          0
# shipping_cost         0
# profit_margin         0
# customer_age          0
# customer_gender       0
# dtype: int64

# %% [markdown]
# ###Check for duplicates

# %%
#checking duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#unique items in each column
df.nunique()
# Out:
# order_id              34500
# customer_id            7903
# product_id            24912
# category                  7
# price                 17274
# discount                  6
# quantity                  5
# payment_method            6
# order_date              731
# delivery_time_days       10
# region                    5
# returned                  2
# total_amount          18800
# shipping_cost          1304
# profit_margin          9603
# customer_age             52
# customer_gender           3
# dtype: int64

# %% [markdown]
# ###Check column names

# %%
#Check column names

df.columns.tolist()
# Out:
# ['order_id',
#  'customer_id',
#  'product_id',
#  'category',
#  'price',
#  'discount',
#  'quantity',
#  'payment_method',
#  'order_date',
#  'delivery_time_days',
#  'region',
#  'returned',
#  'total_amount',
#  'shipping_cost',
#  'profit_margin',
#  'customer_age',
#  'customer_gender']

# %%
## convert order_date to proper datetime

df["order_date"] = pd.to_datetime(df["order_date"])

# %% [markdown]
# ###Descriptive Statistics

# %%
df.describe()
# Out:
#               price      discount      quantity  \
# count  34500.000000  34500.000000  34500.000000
# mean     119.391632      0.049291      1.490725
# min        1.010000      0.000000      1.000000
# 25%       16.690000      0.000000      1.000000
# 50%       45.660000      0.000000      1.000000
# 75%      130.950000      0.100000      2.000000
# max     2930.470000      0.300000      5.000000
# std      195.620477      0.069894      0.932270
#
#                           order_date  delivery_time_days  total_amount  \
# count                          34500        34500.000000  34500.000000
# mean   2024-09-13 13:39:17.843478272            4.814203    170.008494
# min              2023-09-12 00:00:00            3.000000      0.820000
# 25%              2024-03-14 00:00:00            4.000000     19.710000
# 50%              2024-09-16 00:00:00            5.000000     56.820000
# 75%              2025-03-17 00:00:00            6.000000    168.530000
# ...

# %%
df.describe(include = 'object')
# Out:
#        order_id customer_id product_id category payment_method region  \
# count     34500       34500      34500    34500          34500  34500
# unique    34500        7903      24912        7              6      5
# top     O134499      C16704    P200645  Fashion    Credit Card  South
# freq          1          13          7     6254          12170   7584
#
#        returned customer_gender
# count     34500           34500
# unique        2               3
# top          No          Female
# freq      32597           16818

# %%
#verifying the total amount
df["calculated_amount"] = (
    df["price"] * df["quantity"] * (1 - df["discount"])
)

# %%
df[["price", "quantity", "discount", "total_amount", "calculated_amount"]].head(10)
# Out:
#     price  quantity  discount  total_amount  calculated_amount
# 0  164.08         1      0.15        139.47           139.4680
# 1   24.73         1      0.00         24.73            24.7300
# 2  175.58         1      0.05        166.80           166.8010
# 3   63.67         1      0.00         63.67            63.6700
# 4   16.33         1      0.15         13.88            13.8805
# 5   53.91         2      0.10         97.04            97.0380
# 6  266.50         1      0.00        266.50           266.5000
# 7    9.98         1      0.00          9.98             9.9800
# 8    6.61         1      0.05          6.28             6.2795
# 9   10.91         1      0.00         10.91            10.9100

# %%
df.drop('calculated_amount', axis=1, inplace = True)

# %% [markdown]
# ###Since we have not made any alterations we will use the same dataset for power BI
